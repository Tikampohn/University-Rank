# %%
import pandas as pd
import requests #pretend to be web browser
import io
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url='https://www.macrotrends.net/countries/CHN/china/unemployment-rate'

# %%
r=requests.get(url,headers={'user-agent':'Mozilla'})
if r.ok:
    #r.text
    dfs=pd.read_html(io.StringIO(r.text))
    print(len(dfs))
# Out:
# 4

# %%
dfs[1]
# Out:
#    China Unemployment Rate - Historical Data                        \
#                                         Year Unemployment Rate (%)
# 0                                       2022                 4.89%
# 1                                       2021                 4.55%
# 2                                       2020                 5.00%
# 3                                       2019                 4.56%
# 4                                       2018                 4.31%
# 5                                       2017                 4.47%
# 6                                       2016                 4.56%
# 7                                       2015                 4.65%
# 8                                       2014                 4.63%
# 9                                       2013                 4.60%
# 10                                      2012                 4.58%
# 11                                      2011                 4.55%
# 12                                      2010                 4.53%
# 13                                      2009                 4.72%
# 14                                      2008                 4.59%
# 15                                      2007                 4.35%
# 16                                      2006                 4.43%
# 17                                      2005                 4.52%
# 18                                      2004                 4.49%
# 19                                      2003                 4.58%
# 20                                      2002                 4.24%
# 21                                      2001                 3.80%
# 22                                      2000                 3.26%
# 23                                      1999                 3.25%
# 24                                      1998                 3.24%
# 25                                      1997                 3.23%
# 26                                      1996                 3.12%
# 27                                      1995                 3.00%
# 28                                      1994                 2.90%
# 29                                      1993                 2.69%
# 30                                      1992                 2.37%
# 31                                      1991                 2.37%
#
#
#    Annual Change
# 0          0.34%
# 1         -0.45%
# 2          0.44%
# 3          0.25%
# 4         -0.16%
# 5         -0.09%
# 6         -0.09%
# 7          0.02%
# 8          0.03%
# 9          0.02%
# 10         0.03%
# 11         0.02%
# 12        -0.19%
# 13         0.13%
# 14         0.24%
# 15        -0.08%
# 16        -0.09%
# 17         0.03%
# 18        -0.09%
# 19         0.34%
# 20         0.44%
# 21         0.54%
# 22         0.01%
# 23         0.01%
# 24         0.01%
# 25         0.11%
# 26         0.12%
# 27         0.10%
# 28         0.21%
# 29         0.32%
# 30         0.00%
# 31         0.00%
